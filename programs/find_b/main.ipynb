# %%
from functions import *

a_vec = [65, 97, 385, 385, 85, 385, 289, 193, 461, 289, 65, 257]
# a_vec = [763, 679, 397, 61, 697, 373, 289, 257, 625, 41, 193, 449]


Ga, Gb = gen_g_mat(a_vec)
cycles = gen_cycles(6)
hx, hz = gen_h_xz()
constraints = gen_constraints(Gb, a_vec, cycles, hx, hz)

b_vec = solve_with_z3(Ga, constraints)

# %%
print(b_vec)
# Out:
# None
