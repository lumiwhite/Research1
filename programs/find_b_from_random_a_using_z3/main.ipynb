# %%
from functions import *

# %%
import sys
import os
from datetime import datetime

log_dir = 'log'
os.makedirs(log_dir, exist_ok=True)

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
log_filename = os.path.join(log_dir, f"{timestamp}_search_progress.log")
print(f"探索の進捗を {log_filename} に記録します。")
original_stdout = sys.stdout

f = open(log_filename, 'w', encoding='utf-8', buffering=1)

try:
    sys.stdout = f
    
    print(f"{timestamp} : 探索を開始...", flush=True) 
    
    cycles = gen_cycles(4)
    h_x, h_z = gen_h_xz()
    
    a_vec, b_list = find_b_from_random_a()
    
finally:
    sys.stdout = original_stdout
    f.close()

print(f"探索が完了し、ログへの書き込みを終了した。保存先: {log_filename}")
# Out:
# 探索の進捗を log\20260313_143102_search_progress.log に記録します。
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 21
#      16     sys.stdout = f
#      18     print(f"{timestamp} : 探索を開始...", flush=True)
# ---> 21     a_vec, b_list = find_b_from_random_a()
#      23 finally:
#      24     sys.stdout = original_stdout
#
# File c:\Users\black\Research1\programs\find_b_from_random_a_using_z3\functions.py:303, in find_b_from_random_a(p_val)
#     300     expr = Sum([BitVecVal(int(row[j]), 32) * b[j] for j in range(L)])
#     301     solver.add(expr % P != ZERO)
# --> 303 if solver.check() == sat:
#     304     model = solver.model()
#     305     return a_vec, [model[x].as_long() for x in b]
#
# File c:\Users\black\Research1\.venv\Lib\site-packages\z3\z3.py:7309, in Solver.check(self, *assumptions)
#    7307 for i in range(num):
#    7308     _assumptions[i] = s.cast(assumptions[i]).as_ast()
# -> 7309 r = Z3_solver_check_assumptions(self.ctx.ref(), self.solver, num, _assumptions)
#    7310 return CheckSatResult(r)
#
# File c:\Users\black\Research1\.venv\Lib\site-packages\z3\z3core.py:4331, in Z3_solver_check_assumptions(a0, a1, a2, a3, _elems)
#    4330 def Z3_solver_check_assumptions(a0, a1, a2, a3, _elems=Elementaries(_lib.Z3_solver_check_assumptions)):
# -> 4331   r = _elems.f(a0, a1, a2, a3)
#    4332   _elems.Check(a0)
#    4333   return r
#
# KeyboardInterrupt:

# %%
from functions import *
cycles = gen_cycles(6)
h_x, h_z = gen_h_xz()

a, b = find_b_from_random_a(cycles, h_x, h_z)
# Out:
# 試行回数: 1
# 試行回数: 2
# 試行回数: 3
# 試行回数: 4
# 試行回数: 5
# 試行回数: 6
# 試行回数: 7
# 試行回数: 8
# 試行回数: 9
# 試行回数: 10
# 試行回数: 11
# 試行回数: 12
# 試行回数: 13
# 試行回数: 14
# 試行回数: 15
# 試行回数: 16
# 試行回数: 17
# 試行回数: 18
# 試行回数: 19
# 試行回数: 20
# 試行回数: 21
# 試行回数: 22
# 試行回数: 23
# 試行回数: 24
# 試行回数: 25
# 試行回数: 26
# 試行回数: 27
# 試行回数: 28
# 試行回数: 29
# 試行回数: 30
# 試行回数: 31
# 試行回数: 32
# 試行回数: 33
# 試行回数: 34
# 試行回数: 35
# 試行回数: 36

# %%
a
# Out:
# [763, 679, 397, 61, 697, 373, 289, 257, 625, 41, 193, 449]

# %%
b
# Out:
# [543, 729, 498, 378, 276, 750, 560, 0, 744, 60, 288, 288]
