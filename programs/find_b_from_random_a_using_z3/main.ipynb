# %%
from functions import *

# %%
def find_b_bitvec(a_vec, girth, count):
    Ga, Gb = gen_g_mat(a_vec)
    constraints = gen_constraints(Gb, a_vec, girth)
    return solve_with_bitvec(Ga, constraints, count)

# %%
a_vec = [763, 679, 397, 61, 697, 373, 
         289, 257, 625, 41, 193, 449]

# %%
print(find_b_bitvec(a_vec, 6, 10))
# Out:
# 個別に回避すべき禁止制約（超平面）の数: 1671
# [[15, 489, 18, 762, 660, 174, 48, 384, 488, 764, 160, 544], [117, 99, 198, 510, 60, 378, 656, 512, 760, 84, 96, 352], [261, 99, 198, 510, 60, 378, 656, 512, 760, 84, 96, 352], [261, 483, 198, 510, 60, 378, 656, 512, 760, 84, 96, 352], [513, 567, 462, 294, 396, 306, 80, 0, 24, 644, 736, 736], [513, 279, 462, 294, 396, 306, 80, 0, 24, 644, 736, 736], [657, 279, 462, 294, 396, 306, 80, 0, 24, 644, 736, 736], [657, 279, 462, 294, 396, 306, 80, 384, 24, 644, 736, 736], [657, 279, 462, 294, 300, 306, 80, 384, 24, 644, 736, 736], [657, 279, 462, 294, 300, 306, 80, 384, 24, 260, 736, 736]]
