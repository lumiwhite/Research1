# %%
from programs.find_fg.sequential.functions import *

# %%
# a_vec: [71, 107, 227, 107, 131, 587, 179, 551, 191, 407, 431, 251]
# b_vec: [195, 642, 703, 436, 208, 129, 571, 214, 575, 431, 72, 294]
# a_vec: [623, 587, 59, 671, 683, 107, 755, 467, 239, 323, 371, 95]
# b_vec: [129, 498, 249, 85, 276, 77, 727, 564, 671, 699, 366, 747]

# %%
P = 768
L = 12
L_H = 12//2
J = 3

# %%
# 探索の設定
a_vec = [None] * L
b_vec = [None] * L
backtrack_counts = [0] * L  # 各インデックスでのバックトラック（失敗）回数を記録
RESET_LIMIT = 3             # 同じインデックスにN回戻ってきたら0までリセット

idx = 0
cycles = gen_cycles(6)
cx, cz = get_func_idx(cycles)

while idx < L:
    print(f"\rCurrent Index: {idx} | History: {a_vec[:idx]}", end="")
    
    # 序盤のインデックス (idx < 3) は、後の自由度を確保するため
    # 1つの 'a' に固執せず、早めに切り替える（max_attempt1を小さくする）
    max_a = 50 if idx < 3 else 400
    
    res = generate_random_apm(a_vec, b_vec, cx, cz, idx, max_attempt1=max_a)
    
    if res is not None:
        # 探索成功：次のステップへ
        a_vec[idx], b_vec[idx] = res
        # 進展した場合は、その先の失敗カウントをリセットしておく
        if idx + 1 < L:
            backtrack_counts[idx + 1] = 0
        idx += 1
    else:
        # 探索失敗：バックトラッキング
        idx -= 1
        
        if idx < 0:
            print("\n全ての組み合わせを試行しましたが解が見つかりませんでした。")
            break
            
        # 戻った先のインデックスの失敗回数をカウント
        backtrack_counts[idx] += 1
        
        # リセット閾値に達したか判定
        if backtrack_counts[idx] >= RESET_LIMIT:
            print(f"\n【Reset】Index {idx} で停滞（{backtrack_counts[idx]}回目）。Index 0 からやり直します。")
            idx = 0
            a_vec = [None] * L
            b_vec = [None] * L
            backtrack_counts = [0] * L # 全てのカウンタをリセット
        else:
            print(f"\nIndex {idx+1} 失敗。Index {idx} へ戻ります (累積失敗: {backtrack_counts[idx]})")
            # 失敗した箇所以降をクリア
            for k in range(idx + 1, L):
                a_vec[k] = b_vec[k] = None

print("\nFinal Results:")
print("a_vec:", a_vec)
print("b_vec:", b_vec)
# Out:
# Current Index: 0 | History: []a=383, b=179を見つけました。
# Current Index: 1 | History: [383]a=95, b=611を見つけました。
# Current Index: 2 | History: [383, 95]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [383]a=731, b=521を見つけました。
# Current Index: 2 | History: [383, 731]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [383]a=515, b=269を見つけました。
# Current Index: 2 | History: [383, 515]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=83, b=479を見つけました。
# Current Index: 1 | History: [83]a=155, b=731を見つけました。
# Current Index: 2 | History: [83, 155]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [83]a=275, b=767を見つけました。
# Current Index: 2 | History: [83, 275]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [83]a=419, b=119を見つけました。
# Current Index: 2 | History: [83, 419]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=275, b=448を見つけました。
# Current Index: 1 | History: [275]a=491, b=64を見つけました。
# Current Index: 2 | History: [275, 491]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [275]a=467, b=64を見つけました。
# Current Index: 2 | History: [275, 467]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [275]a=587, b=64を見つけました。
# Current Index: 2 | History: [275, 587]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=551, b=667を見つけました。
# Current Index: 1 | History: [551]a=743, b=379を見つけました。
# Current Index: 2 | History: [551, 743]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [551]a=23, b=595を見つけました。
# Current Index: 2 | History: [551, 23]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [551]a=455, b=619を見つけました。
# Current Index: 2 | History: [551, 455]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=503, b=698を見つけました。
# Current Index: 1 | History: [503]a=719, b=290を見つけました。
# Current Index: 2 | History: [503, 719]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [503]a=335, b=290を見つけました。
# Current Index: 2 | History: [503, 335]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [503]a=59, b=278を見つけました。
# Current Index: 2 | History: [503, 59]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=227, b=703を見つけました。
# Current Index: 1 | History: [227]a=407, b=709を見つけました。
# Current Index: 2 | History: [227, 407]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [227]a=287, b=193を見つけました。
# Current Index: 2 | History: [227, 287]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [227]a=335, b=553を見つけました。
# Current Index: 2 | History: [227, 335]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=179, b=705を見つけました。
# Current Index: 1 | History: [179]a=359, b=171を見つけました。
# Current Index: 2 | History: [179, 359]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [179]a=635, b=69を見つけました。
# Current Index: 2 | History: [179, 635]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [179]a=515, b=681を見つけました。
# Current Index: 2 | History: [179, 515]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=251, b=241を見つけました。
# Current Index: 1 | History: [251]a=47, b=115を見つけました。
# Current Index: 2 | History: [251, 47]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [251]a=731, b=289を見つけました。
# Current Index: 2 | History: [251, 731]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [251]a=635, b=49を見つけました。
# Current Index: 2 | History: [251, 635]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=551, b=450を見つけました。
# Current Index: 1 | History: [551]a=527, b=186を見つけました。
# Current Index: 2 | History: [551, 527]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [551]a=47, b=666を見つけました。
# Current Index: 2 | History: [551, 47]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [551]a=311, b=114を見つけました。
# Current Index: 2 | History: [551, 311]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=407, b=699を見つけました。
# Current Index: 1 | History: [407]a=143, b=759を見つけました。
# Current Index: 2 | History: [407, 143]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [407]a=419, b=33を見つけました。
# Current Index: 2 | History: [407, 419]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [407]a=215, b=603を見つけました。
# Current Index: 2 | History: [407, 215]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=515, b=486を見つけました。
# Current Index: 1 | History: [515]a=299, b=222を見つけました。
# Current Index: 2 | History: [515, 299]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [515]a=215, b=162を見つけました。
# Current Index: 2 | History: [515, 215]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [515]a=755, b=438を見つけました。
# Current Index: 2 | History: [515, 755]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=575, b=170を見つけました。
# Current Index: 1 | History: [575]a=179, b=422を見つけました。
# Current Index: 2 | History: [575, 179]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [575]a=179, b=422を見つけました。
# Current Index: 2 | History: [575, 179]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [575]a=539, b=158を見つけました。
# Current Index: 2 | History: [575, 539]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=419, b=43を見つけました。
# Current Index: 1 | History: [419]a=443, b=751を見つけました。
# Current Index: 2 | History: [419, 443]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [419]a=371, b=547を見つけました。
# Current Index: 2 | History: [419, 371]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [419]a=83, b=499を見つけました。
# Current Index: 2 | History: [419, 83]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=23, b=373を見つけました。
# Current Index: 1 | History: [23]a=407, b=565を見つけました。
# Current Index: 2 | History: [23, 407]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [23]a=107, b=331を見つけました。
# Current Index: 2 | History: [23, 107]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [23]a=95, b=337を見つけました。
# Current Index: 2 | History: [23, 95]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=659, b=682を見つけました。
# Current Index: 1 | History: [659]a=395, b=322を見つけました。
# Current Index: 2 | History: [659, 395]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [659]a=227, b=442を見つけました。
# Current Index: 2 | History: [659, 227]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [659]a=527, b=502を見つけました。
# Current Index: 2 | History: [659, 527]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=419, b=672を見つけました。
# Current Index: 1 | History: [419]a=47, b=480を見つけました。
# Current Index: 2 | History: [419, 47]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [419]a=527, b=480を見つけました。
# Current Index: 2 | History: [419, 527]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [419]a=539, b=288を見つけました。
# Current Index: 2 | History: [419, 539]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=251, b=736を見つけました。
# Current Index: 1 | History: [251]a=611, b=736を見つけました。
# Current Index: 2 | History: [251, 611]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [251]a=359, b=544を見つけました。
# Current Index: 2 | History: [251, 359]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [251]a=635, b=352を見つけました。
# Current Index: 2 | History: [251, 635]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=671, b=662を見つけました。
# Current Index: 1 | History: [671]a=311, b=14を見つけました。
# Current Index: 2 | History: [671, 311]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [671]a=431, b=614を見つけました。
# Current Index: 2 | History: [671, 431]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [671]a=551, b=446を見つけました。
# Current Index: 2 | History: [671, 551]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=143, b=313を見つけました。
# Current Index: 1 | History: [143]a=563, b=103を見つけました。
# Current Index: 2 | History: [143, 563]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [143]a=239, b=265を見つけました。
# Current Index: 2 | History: [143, 239]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [143]a=251, b=259を見つけました。
# Current Index: 2 | History: [143, 251]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=167, b=681を見つけました。
# Current Index: 1 | History: [167]a=755, b=123を見つけました。
# Current Index: 2 | History: [167, 755]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [167]a=311, b=129を見つけました。
# Current Index: 2 | History: [167, 311]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [167]a=155, b=567を見つけました。
# Current Index: 2 | History: [167, 155]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=539, b=453を見つけました。
# Current Index: 1 | History: [539]a=671, b=183を見つけました。
# Current Index: 2 | History: [539, 671]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [539]a=287, b=759を見つけました。
# Current Index: 2 | History: [539, 287]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [539]a=611, b=201を見つけました。
# Current Index: 2 | History: [539, 611]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=155, b=222を見つけました。
# Current Index: 1 | History: [155]a=59, b=318を見つけました。
# Current Index: 2 | History: [155, 59]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [155]a=731, b=414を見つけました。
# Current Index: 2 | History: [155, 731]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [155]a=155, b=222を見つけました。
# Current Index: 2 | History: [155, 155]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=431, b=677を見つけました。
# Current Index: 1 | History: [431]a=119, b=209を見つけました。
# Current Index: 2 | History: [431, 119]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [431]a=23, b=449を見つけました。
# Current Index: 2 | History: [431, 23]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [431]a=683, b=95を見つけました。
# Current Index: 2 | History: [431, 683]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=131, b=41を見つけました。
# Current Index: 1 | History: [131]a=227, b=473を見つけました。
# Current Index: 2 | History: [131, 227]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [131]a=503, b=371を見つけました。
# Current Index: 2 | History: [131, 503]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [131]a=203, b=749を見つけました。
# Current Index: 2 | History: [131, 203]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=479, b=9を見つけました。
# Current Index: 1 | History: [479]a=395, b=99を見つけました。
# Current Index: 2 | History: [479, 395]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [479]a=203, b=195を見つけました。
# Current Index: 2 | History: [479, 203]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [479]a=707, b=39を見つけました。
# Current Index: 2 | History: [479, 707]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=311, b=645を見つけました。
# Current Index: 1 | History: [311]a=467, b=375を見つけました。
# Current Index: 2 | History: [311, 467]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [311]a=119, b=741を見つけました。
# Current Index: 2 | History: [311, 119]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [311]a=23, b=405を見つけました。
# Current Index: 2 | History: [311, 23]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=599, b=441を見つけました。
# Current Index: 1 | History: [599]a=587, b=183を見つけました。
# Current Index: 2 | History: [599, 587]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [599]a=359, b=657を見つけました。
# Current Index: 2 | History: [599, 359]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [599]a=299, b=135を見つけました。
# Current Index: 2 | History: [599, 299]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=263, b=366を見つけました。
# Current Index: 1 | History: [263]a=527, b=342を見つけました。
# Current Index: 2 | History: [263, 527]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [263]a=575, b=198を見つけました。
# Current Index: 2 | History: [263, 575]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [263]a=755, b=42を見つけました。
# Current Index: 2 | History: [263, 755]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=215, b=437を見つけました。
# Current Index: 1 | History: [215]a=155, b=659を見つけました。
# Current Index: 2 | History: [215, 155]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [215]a=371, b=551を見つけました。
# Current Index: 2 | History: [215, 371]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [215]a=323, b=575を見つけました。
# Current Index: 2 | History: [215, 323]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=227, b=98を見つけました。
# Current Index: 1 | History: [227]a=371, b=626を見つけました。
# Current Index: 2 | History: [227, 371]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [227]a=719, b=590を見つけました。
# Current Index: 2 | History: [227, 719]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [227]a=251, b=506を見つけました。
# Current Index: 2 | History: [227, 251]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=155, b=267を見つけました。
# Current Index: 1 | History: [155]a=707, b=471を見つけました。
# Current Index: 2 | History: [155, 707]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [155]a=719, b=417を見つけました。
# Current Index: 2 | History: [155, 719]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [155]a=671, b=249を見つけました。
# Current Index: 2 | History: [155, 671]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=239, b=414を見つけました。
# Current Index: 1 | History: [239]a=371, b=450を見つけました。
# Current Index: 2 | History: [239, 371]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [239]a=731, b=234を見つけました。
# Current Index: 2 | History: [239, 731]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [239]a=695, b=678を見つけました。
# Current Index: 2 | History: [239, 695]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=155, b=584を見つけました。
# Current Index: 1 | History: [155]a=47, b=344を見つけました。
# Current Index: 2 | History: [155, 47]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [155]a=203, b=8を見つけました。
# Current Index: 2 | History: [155, 203]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [155]a=647, b=440を見つけました。
# Current Index: 2 | History: [155, 647]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=71, b=49を見つけました。
# Current Index: 1 | History: [71]a=275, b=115を見つけました。
# Current Index: 2 | History: [71, 275]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [71]a=407, b=361を見つけました。
# Current Index: 2 | History: [71, 407]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [71]a=11, b=7を見つけました。
# Current Index: 2 | History: [71, 11]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=599, b=175を見つけました。
# Current Index: 1 | History: [599]a=611, b=637を見つけました。
# Current Index: 2 | History: [599, 611]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [599]a=611, b=253を見つけました。
# Current Index: 2 | History: [599, 611]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [599]a=623, b=331を見つけました。
# Current Index: 2 | History: [599, 623]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=395, b=200を見つけました。
# Current Index: 1 | History: [395]a=671, b=728を見つけました。
# Current Index: 2 | History: [395, 671]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [395]a=263, b=632を見つけました。
# Current Index: 2 | History: [395, 263]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [395]a=47, b=536を見つけました。
# Current Index: 2 | History: [395, 47]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=107, b=700を見つけました。
# Current Index: 1 | History: [107]a=251, b=28を見つけました。
# Current Index: 2 | History: [107, 251]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [107]a=491, b=316を見つけました。
# Current Index: 2 | History: [107, 491]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [107]a=587, b=124を見つけました。
# Current Index: 2 | History: [107, 587]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=299, b=502を見つけました。
# Current Index: 1 | History: [299]a=659, b=142を見つけました。
# Current Index: 2 | History: [299, 659]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [299]a=47, b=562を見つけました。
# Current Index: 2 | History: [299, 47]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [299]a=671, b=322を見つけました。
# Current Index: 2 | History: [299, 671]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=623, b=668を見つけました。
# Current Index: 1 | History: [623]a=83, b=356を見つけました。
# Current Index: 2 | History: [623, 83]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [623]a=707, b=68を見つけました。
# Current Index: 2 | History: [623, 707]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [623]a=539, b=500を見つけました。
# Current Index: 2 | History: [623, 539]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=383, b=37を見つけました。
# Current Index: 1 | History: [383]a=671, b=469を見つけました。
# Current Index: 2 | History: [383, 671]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [383]a=251, b=559を見つけました。
# Current Index: 2 | History: [383, 251]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [383]a=203, b=295を見つけました。
# Current Index: 2 | History: [383, 203]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=599, b=651を見つけました。
# Current Index: 1 | History: [599]a=143, b=39を見つけました。
# Current Index: 2 | History: [599, 143]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [599]a=503, b=603を見つけました。
# Current Index: 2 | History: [599, 503]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [599]a=647, b=675を見つけました。
# Current Index: 2 | History: [599, 647]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=35, b=487を見つけました。
# Current Index: 1 | History: [35]a=407, b=733を見つけました。
# Current Index: 2 | History: [35, 407]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [35]a=23, b=541を見つけました。
# Current Index: 2 | History: [35, 23]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [35]a=299, b=451を見つけました。
# Current Index: 2 | History: [35, 299]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=395, b=574を見つけました。
# Current Index: 1 | History: [395]a=335, b=586を見つけました。
# Current Index: 2 | History: [395, 335]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [395]a=515, b=550を見つけました。
# Current Index: 2 | History: [395, 515]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [395]a=347, b=430を見つけました。
# Current Index: 2 | History: [395, 347]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=611, b=278を見つけました。
# Current Index: 1 | History: [611]a=599, b=722を見つけました。
# Current Index: 2 | History: [611, 599]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [611]a=395, b=590を見つけました。
# Current Index: 2 | History: [611, 395]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [611]a=467, b=614を見つけました。
# Current Index: 2 | History: [611, 467]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=47, b=515を見つけました。
# Current Index: 1 | History: [47]a=107, b=185を見つけました。
# Current Index: 2 | History: [47, 107]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [47]a=263, b=95を見つけました。
# Current Index: 2 | History: [47, 263]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [47]a=383, b=203を見つけました。
# Current Index: 2 | History: [47, 383]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=479, b=391を見つけました。
# Current Index: 1 | History: [479]a=383, b=727を見つけました。
# Current Index: 2 | History: [479, 383]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [479]a=455, b=283を見つけました。
# Current Index: 2 | History: [479, 455]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [479]a=167, b=139を見つけました。
# Current Index: 2 | History: [479, 167]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=419, b=764を見つけました。
# Current Index: 1 | History: [419]a=203, b=44を見つけました。
# Current Index: 2 | History: [419, 203]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [419]a=155, b=524を見つけました。
# Current Index: 2 | History: [419, 155]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [419]a=575, b=452を見つけました。
# Current Index: 2 | History: [419, 575]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=671, b=526を見つけました。
# Current Index: 1 | History: [671]a=83, b=610を見つけました。
# Current Index: 2 | History: [671, 83]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [671]a=23, b=454を見つけました。
# Current Index: 2 | History: [671, 23]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [671]a=419, b=178を見つけました。
# Current Index: 2 | History: [671, 419]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=611, b=247を見つけました。
# Current Index: 1 | History: [611]a=359, b=709を見つけました。
# Current Index: 2 | History: [611, 359]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [611]a=107, b=403を見つけました。
# Current Index: 2 | History: [611, 107]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [611]a=47, b=385を見つけました。
# Current Index: 2 | History: [611, 47]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=107, b=688を見つけました。
# Current Index: 1 | History: [107]a=443, b=688を見つけました。
# Current Index: 2 | History: [107, 443]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [107]a=215, b=208を見つけました。
# Current Index: 2 | History: [107, 215]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [107]a=383, b=16を見つけました。
# Current Index: 2 | History: [107, 383]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=719, b=472を見つけました。
# Current Index: 1 | History: [719]a=191, b=280を見つけました。
# Current Index: 2 | History: [719, 191]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [719]a=419, b=232を見つけました。
# Current Index: 2 | History: [719, 419]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [719]a=755, b=424を見つけました。
# Current Index: 2 | History: [719, 755]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=575, b=593を見つけました。
# Current Index: 1 | History: [575]a=311, b=533を見つけました。
# Current Index: 2 | History: [575, 311]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [575]a=455, b=77を見つけました。
# Current Index: 2 | History: [575, 455]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [575]a=683, b=635を見つけました。
# Current Index: 2 | History: [575, 683]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=107, b=231を見つけました。
# Current Index: 1 | History: [107]a=119, b=105を見つけました。
# Current Index: 2 | History: [107, 119]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [107]a=71, b=609を見つけました。
# Current Index: 2 | History: [107, 71]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [107]a=179, b=627を見つけました。
# Current Index: 2 | History: [107, 179]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=671, b=50を見つけました。
# Current Index: 1 | History: [671]a=311, b=218を見つけました。
# Current Index: 2 | History: [671, 311]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [671]a=635, b=758を見つけました。
# Current Index: 2 | History: [671, 635]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [671]a=23, b=506を見つけました。
# Current Index: 2 | History: [671, 23]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=407, b=661を見つけました。
# Current Index: 1 | History: [407]a=347, b=115を見つけました。
# Current Index: 2 | History: [407, 347]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [407]a=107, b=235を見つけました。
# Current Index: 2 | History: [407, 107]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [407]a=467, b=55を見つけました。
# Current Index: 2 | History: [407, 467]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=371, b=522を見つけました。
# Current Index: 1 | History: [371]a=695, b=126を見つけました。
# Current Index: 2 | History: [371, 695]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [371]a=431, b=534を見つけました。
# Current Index: 2 | History: [371, 431]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [371]a=695, b=510を見つけました。
# Current Index: 2 | History: [371, 695]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=215, b=349を見つけました。
# Current Index: 1 | History: [215]a=59, b=91を見つけました。
# Current Index: 2 | History: [215, 59]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [215]a=659, b=463を見つけました。
# Current Index: 2 | History: [215, 659]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [215]a=611, b=295を見つけました。
# Current Index: 2 | History: [215, 611]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=455, b=207を見つけました。
# Current Index: 1 | History: [455]a=383, b=411を見つけました。
# Current Index: 2 | History: [455, 383]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [455]a=731, b=321を見つけました。
# Current Index: 2 | History: [455, 731]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [455]a=455, b=207を見つけました。
# Current Index: 2 | History: [455, 455]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=755, b=600を見つけました。
# Current Index: 1 | History: [755]a=731, b=696を見つけました。
# Current Index: 2 | History: [755, 731]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [755]a=131, b=408を見つけました。
# Current Index: 2 | History: [755, 131]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [755]a=83, b=600を見つけました。
# Current Index: 2 | History: [755, 83]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=179, b=764を見つけました。
# Current Index: 1 | History: [179]a=119, b=308を見つけました。
# Current Index: 2 | History: [179, 119]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [179]a=599, b=500を見つけました。
# Current Index: 2 | History: [179, 599]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [179]a=251, b=620を見つけました。
# Current Index: 2 | History: [179, 251]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=167, b=259を見つけました。
# Current Index: 1 | History: [167]a=551, b=451を見つけました。
# Current Index: 2 | History: [167, 551]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [167]a=503, b=43を見つけました。
# Current Index: 2 | History: [167, 503]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [167]a=623, b=295を見つけました。
# Current Index: 2 | History: [167, 623]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=95, b=94を見つけました。
# Current Index: 1 | History: [95]a=47, b=46を見つけました。
# Current Index: 2 | History: [95, 47]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [95]a=743, b=358を見つけました。
# Current Index: 2 | History: [95, 743]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [95]a=491, b=106を見つけました。
# Current Index: 2 | History: [95, 491]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=11, b=607を見つけました。
# Current Index: 1 | History: [11]a=443, b=487を見つけました。
# Current Index: 2 | History: [11, 443]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [11]a=659, b=619を見つけました。
# Current Index: 2 | History: [11, 659]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [11]a=563, b=475を見つけました。
# Current Index: 2 | History: [11, 563]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=431, b=765を見つけました。
# Current Index: 1 | History: [431]a=83, b=3を見つけました。
# Current Index: 2 | History: [431, 83]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [431]a=239, b=477を見つけました。
# Current Index: 2 | History: [431, 239]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [431]a=359, b=753を見つけました。
# Current Index: 2 | History: [431, 359]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=119, b=16を見つけました。
# Current Index: 1 | History: [119]a=467, b=304を見つけました。
# Current Index: 2 | History: [119, 467]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [119]a=551, b=400を見つけました。
# Current Index: 2 | History: [119, 551]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [119]a=491, b=496を見つけました。
# Current Index: 2 | History: [119, 491]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=671, b=646を見つけました。
# Current Index: 1 | History: [671]a=515, b=538を見つけました。
# Current Index: 2 | History: [671, 515]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [671]a=539, b=466を見つけました。
# Current Index: 2 | History: [671, 539]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [671]a=215, b=478を見つけました。
# Current Index: 2 | History: [671, 215]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=179, b=629を見つけました。
# Current Index: 1 | History: [179]a=311, b=47を見つけました。
# Current Index: 2 | History: [179, 311]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [179]a=755, b=533を見つけました。
# Current Index: 2 | History: [179, 755]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [179]a=503, b=527を見つけました。
# Current Index: 2 | History: [179, 503]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=311, b=300を見つけました。
# Current Index: 1 | History: [311]a=479, b=636を見つけました。
# Current Index: 2 | History: [311, 479]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [311]a=35, b=132を見つけました。
# Current Index: 2 | History: [311, 35]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [311]a=719, b=348を見つけました。
# Current Index: 2 | History: [311, 719]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=671, b=7を見つけました。
# Current Index: 1 | History: [671]a=23, b=163を見つけました。
# Current Index: 2 | History: [671, 23]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [671]a=371, b=577を見つけました。
# Current Index: 2 | History: [671, 371]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [671]a=659, b=337を見つけました。
# Current Index: 2 | History: [671, 659]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=95, b=212を見つけました。
# Current Index: 1 | History: [95]a=479, b=212を見つけました。
# Current Index: 2 | History: [95, 479]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [95]a=503, b=356を見つけました。
# Current Index: 2 | History: [95, 503]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [95]a=575, b=404を見つけました。
# Current Index: 2 | History: [95, 575]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=107, b=674を見つけました。
# Current Index: 1 | History: [107]a=587, b=386を見つけました。
# Current Index: 2 | History: [107, 587]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [107]a=683, b=98を見つけました。
# Current Index: 2 | History: [107, 683]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [107]a=527, b=758を見つけました。
# Current Index: 2 | History: [107, 527]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=599, b=587を見つけました。
# Current Index: 1 | History: [599]a=119, b=731を見つけました。
# Current Index: 2 | History: [599, 119]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [599]a=23, b=299を見つけました。
# Current Index: 2 | History: [599, 23]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [599]a=671, b=239を見つけました。
# Current Index: 2 | History: [599, 671]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=167, b=230を見つけました。
# Current Index: 1 | History: [167]a=443, b=122を見つけました。
# Current Index: 2 | History: [167, 443]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [167]a=35, b=98を見つけました。
# Current Index: 2 | History: [167, 35]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [167]a=647, b=326を見つけました。
# Current Index: 2 | History: [167, 647]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=179, b=465を見つけました。
# Current Index: 1 | History: [179]a=563, b=657を見つけました。
# Current Index: 2 | History: [179, 563]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [179]a=251, b=213を見つけました。
# Current Index: 2 | History: [179, 251]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [179]a=11, b=285を見つけました。
# Current Index: 2 | History: [179, 11]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=119, b=618を見つけました。
# Current Index: 1 | History: [119]a=155, b=390を見つけました。
# Current Index: 2 | History: [119, 155]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [119]a=455, b=282を見つけました。
# Current Index: 2 | History: [119, 455]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [119]a=683, b=630を見つけました。
# Current Index: 2 | History: [119, 683]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=167, b=31を見つけました。
# Current Index: 1 | History: [167]a=587, b=697を見つけました。
# Current Index: 2 | History: [167, 587]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [167]a=515, b=133を見つけました。
# Current Index: 2 | History: [167, 515]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [167]a=443, b=337を見つけました。
# Current Index: 2 | History: [167, 443]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=659, b=249を見つけました。
# Current Index: 1 | History: [659]a=431, b=39を見つけました。
# Current Index: 2 | History: [659, 431]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [659]a=383, b=15を見つけました。
# Current Index: 2 | History: [659, 383]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [659]a=707, b=657を見つけました。
# Current Index: 2 | History: [659, 707]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=59, b=347を見つけました。
# Current Index: 1 | History: [59]a=695, b=749を見つけました。
# Current Index: 2 | History: [59, 695]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [59]a=335, b=65を見つけました。
# Current Index: 2 | History: [59, 335]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [59]a=539, b=491を見つけました。
# Current Index: 2 | History: [59, 539]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=611, b=694を見つけました。
# Current Index: 1 | History: [611]a=707, b=598を見つけました。
# Current Index: 2 | History: [611, 707]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [611]a=71, b=514を見つけました。
# Current Index: 2 | History: [611, 71]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [611]a=719, b=346を見つけました。
# Current Index: 2 | History: [611, 719]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=587, b=109を見つけました。
# Current Index: 1 | History: [587]a=755, b=481を見つけました。
# Current Index: 2 | History: [587, 755]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [587]a=515, b=553を見つけました。
# Current Index: 2 | History: [587, 515]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [587]a=455, b=91を見つけました。
# Current Index: 2 | History: [587, 455]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=371, b=625を見つけました。
# Current Index: 1 | History: [371]a=695, b=643を見つけました。
# Current Index: 2 | History: [371, 695]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [371]a=155, b=613を見つけました。
# Current Index: 2 | History: [371, 155]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [371]a=407, b=499を見つけました。
# Current Index: 2 | History: [371, 407]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=659, b=657を見つけました。
# Current Index: 1 | History: [659]a=695, b=435を見つけました。
# Current Index: 2 | History: [659, 695]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [659]a=251, b=357を見つけました。
# Current Index: 2 | History: [659, 251]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [659]a=575, b=663を見つけました。
# Current Index: 2 | History: [659, 575]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=215, b=159を見つけました。
# Current Index: 1 | History: [215]a=707, b=381を見つけました。
# Current Index: 2 | History: [215, 707]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [215]a=71, b=759を見つけました。
# Current Index: 2 | History: [215, 71]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [215]a=191, b=579を見つけました。
# Current Index: 2 | History: [215, 191]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=671, b=325を見つけました。
# Current Index: 1 | History: [671]a=227, b=379を見つけました。
# Current Index: 2 | History: [671, 227]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [671]a=107, b=487を見つけました。
# Current Index: 2 | History: [671, 107]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [671]a=599, b=313を見つけました。
# Current Index: 2 | History: [671, 599]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=167, b=381を見つけました。
# Current Index: 1 | History: [167]a=743, b=477を見つけました。
# Current Index: 2 | History: [167, 743]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [167]a=635, b=243を見つけました。
# Current Index: 2 | History: [167, 635]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [167]a=743, b=93を見つけました。
# ...
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=707, b=676を見つけました。
# Current Index: 1 | History: [707]a=119, b=76を見つけました。
# Current Index: 2 | History: [707, 119]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [707]a=635, b=532を見つけました。
# Current Index: 2 | History: [707, 635]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [707]a=11, b=52を見つけました。
# Current Index: 2 | History: [707, 11]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=215, b=171を見つけました。
# Current Index: 1 | History: [215]a=119, b=507を見つけました。
# Current Index: 2 | History: [215, 119]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [215]a=635, b=381を見つけました。
# Current Index: 2 | History: [215, 635]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [215]a=671, b=399を見つけました。
# Current Index: 2 | History: [215, 671]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=755, b=275を見つけました。
# Current Index: 1 | History: [755]a=323, b=587を見つけました。
# Current Index: 2 | History: [755, 323]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [755]a=299, b=455を見つけました。
# Current Index: 2 | History: [755, 299]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [755]a=431, b=221を見つけました。
# Current Index: 2 | History: [755, 431]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=563, b=15を見つけました。
# Current Index: 1 | History: [563]a=179, b=591を見つけました。
# Current Index: 2 | History: [563, 179]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [563]a=71, b=405を見つけました。
# Current Index: 2 | History: [563, 71]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [563]a=203, b=291を見つけました。
# Current Index: 2 | History: [563, 203]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=419, b=591を見つけました。
# Current Index: 1 | History: [419]a=479, b=753を見つけました。
# Current Index: 2 | History: [419, 479]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [419]a=575, b=321を見つけました。
# Current Index: 2 | History: [419, 575]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [419]a=443, b=195を見つけました。
# Current Index: 2 | History: [419, 443]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=479, b=214を見つけました。
# Current Index: 1 | History: [479]a=623, b=550を見つけました。
# Current Index: 2 | History: [479, 623]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [479]a=287, b=406を見つけました。
# Current Index: 2 | History: [479, 287]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [479]a=287, b=22を見つけました。
# Current Index: 2 | History: [479, 287]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=179, b=737を見つけました。
# Current Index: 1 | History: [179]a=371, b=449を見つけました。
# Current Index: 2 | History: [179, 371]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [179]a=755, b=257を見つけました。
# Current Index: 2 | History: [179, 755]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [179]a=551, b=107を見つけました。
# Current Index: 2 | History: [179, 551]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=611, b=269を見つけました。
# Current Index: 1 | History: [611]a=179, b=533を見つけました。
# Current Index: 2 | History: [611, 179]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [611]a=203, b=497を見つけました。
# Current Index: 2 | History: [611, 203]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [611]a=191, b=323を見つけました。
# Current Index: 2 | History: [611, 191]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=479, b=540を見つけました。
# Current Index: 1 | History: [479]a=455, b=492を見つけました。
# Current Index: 2 | History: [479, 455]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [479]a=659, b=324を見つけました。
# Current Index: 2 | History: [479, 659]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [479]a=143, b=252を見つけました。
# Current Index: 2 | History: [479, 143]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=587, b=380を見つけました。
# Current Index: 1 | History: [587]a=599, b=452を見つけました。
# Current Index: 2 | History: [587, 599]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [587]a=71, b=740を見つけました。
# Current Index: 2 | History: [587, 71]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [587]a=35, b=140を見つけました。
# Current Index: 2 | History: [587, 35]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=119, b=390を見つけました。
# Current Index: 1 | History: [119]a=419, b=210を見つけました。
# Current Index: 2 | History: [119, 419]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [119]a=95, b=558を見つけました。
# Current Index: 2 | History: [119, 95]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [119]a=587, b=186を見つけました。
# Current Index: 2 | History: [119, 587]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=743, b=678を見つけました。
# Current Index: 1 | History: [743]a=119, b=438を見つけました。
# Current Index: 2 | History: [743, 119]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [743]a=587, b=138を見つけました。
# Current Index: 2 | History: [743, 587]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [743]a=311, b=630を見つけました。
# Current Index: 2 | History: [743, 311]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=635, b=217を見つけました。
# Current Index: 1 | History: [635]a=143, b=475を見つけました。
# Current Index: 2 | History: [635, 143]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [635]a=239, b=331を見つけました。
# Current Index: 2 | History: [635, 239]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [635]a=563, b=133を見つけました。
# Current Index: 2 | History: [635, 563]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=311, b=60を見つけました。
# Current Index: 1 | History: [311]a=299, b=132を見つけました。
# Current Index: 2 | History: [311, 299]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [311]a=683, b=516を見つけました。
# Current Index: 2 | History: [311, 683]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [311]a=179, b=468を見つけました。
# Current Index: 2 | History: [311, 179]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=455, b=127を見つけました。
# Current Index: 1 | History: [455]a=299, b=217を見つけました。
# Current Index: 2 | History: [455, 299]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [455]a=323, b=469を見つけました。
# Current Index: 2 | History: [455, 323]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [455]a=539, b=49を見つけました。
# Current Index: 2 | History: [455, 539]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=275, b=115を見つけました。
# Current Index: 1 | History: [275]a=299, b=55を見つけました。
# Current Index: 2 | History: [275, 299]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [275]a=71, b=433を見つけました。
# Current Index: 2 | History: [275, 71]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [275]a=227, b=619を見つけました。
# Current Index: 2 | History: [275, 227]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=515, b=394を見つけました。
# Current Index: 1 | History: [515]a=47, b=358を見つけました。
# Current Index: 2 | History: [515, 47]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [515]a=251, b=610を見つけました。
# Current Index: 2 | History: [515, 251]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [515]a=143, b=70を見つけました。
# Current Index: 2 | History: [515, 143]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=467, b=402を見つけました。
# Current Index: 1 | History: [467]a=23, b=726を見つけました。
# Current Index: 2 | History: [467, 23]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [467]a=347, b=282を見つけました。
# Current Index: 2 | History: [467, 347]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [467]a=539, b=474を見つけました。
# Current Index: 2 | History: [467, 539]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=707, b=279を見つけました。
# Current Index: 1 | History: [707]a=371, b=255を見つけました。
# Current Index: 2 | History: [707, 371]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [707]a=323, b=87を見つけました。
# Current Index: 2 | History: [707, 323]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [707]a=719, b=609を見つけました。
# Current Index: 2 | History: [707, 719]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=11, b=590を見つけました。
# Current Index: 1 | History: [11]a=323, b=182を見つけました。
# Current Index: 2 | History: [11, 323]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [11]a=35, b=86を見つけました。
# Current Index: 2 | History: [11, 35]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [11]a=491, b=110を見つけました。
# Current Index: 2 | History: [11, 491]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=215, b=263を見つけました。
# Current Index: 1 | History: [215]a=287, b=251を見つけました。
# Current Index: 2 | History: [215, 287]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [215]a=299, b=377を見つけました。
# Current Index: 2 | History: [215, 299]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [215]a=347, b=113を見つけました。
# Current Index: 2 | History: [215, 347]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=647, b=223を見つけました。
# Current Index: 1 | History: [647]a=215, b=679を見つけました。
# Current Index: 2 | History: [647, 215]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [647]a=755, b=13を見つけました。
# Current Index: 2 | History: [647, 755]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 2)
# Current Index: 1 | History: [647]a=707, b=277を見つけました。
# Current Index: 2 | History: [647, 707]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# 【Reset】Index 1 で停滞（3回目）。Index 0 からやり直します。
# Current Index: 0 | History: []a=479, b=6を見つけました。
# Current Index: 1 | History: [479]a=719, b=54を見つけました。
# Current Index: 2 | History: [479, 719]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
#
# Index 2 失敗。Index 1 へ戻ります (累積失敗: 1)
# Current Index: 1 | History: [479]a=623, b=726を見つけました。
# Current Index: 2 | History: [479, 623]50回の試行で解を見つけられませんでした。ひとつ前のインデックス1の探索に戻ります
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 18
#      14 # 序盤のインデックス (idx < 3) は、後の自由度を確保するため
#      15 # 1つの 'a' に固執せず、早めに切り替える（max_attempt1を小さくする）
#      16 max_a = 50 if idx < 3 else 400
# ---> 18 res = generate_random_apm(a_vec, b_vec, cx, cz, idx, max_attempt1=max_a)
#      20 if res is not None:
#      21     # 探索成功：次のステップへ
#      22     a_vec[idx], b_vec[idx] = res
#
# File c:\Users\black\Research\programs\functions.py:235, in generate_random_apm(a_vec, b_vec, cycles_x, cycles_z, idx, P, L, max_attempt1, max_attempt2)
#     233             return a_val, b_val
#     234     # print(f"{max_attempt2}回の試行で解を見つけられませんでした。新しいaを計算します。")
# --> 235 print(f"{max_attempt1}回の試行で解を見つけられませんでした。ひとつ前のインデックス{idx-1}の探索に戻ります")
#     236 return None
#
# File c:\Users\black\Research\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3053, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3051 def write(data, *args, **kwargs):
#    3052     """Write data to both the original destination and the capture dictionary."""
# -> 3053     result = original_write(data, *args, **kwargs)
#    3054     if any(
#    3055         [
#    3056             self.display_pub.is_publishing,
#    (...)   3059         ]
#    3060     ):
#    3061         return result
#
# File c:\Users\black\Research\.venv\Lib\site-packages\ipykernel\iostream.py:689, in OutStream.write(self, string)
#     687     self.pub_thread.schedule(self._flush)
#     688 else:
# --> 689     self._schedule_flush()
#     691 return len(string)
#
# File c:\Users\black\Research\.venv\Lib\site-packages\ipykernel\iostream.py:585, in OutStream._schedule_flush(self)
#     582 def _schedule_in_thread():
#     583     self._io_loop.call_later(self.flush_interval, self._flush)
# --> 585 self.pub_thread.schedule(_schedule_in_thread)
#
# File c:\Users\black\Research\.venv\Lib\site-packages\ipykernel\iostream.py:268, in IOPubThread.schedule(self, f)
#     266     self._events.append(f)
#     267     # wake event thread (message content is ignored)
# --> 268     self._event_pipe.send(b"")
#     269 else:
#     270     f()
#
# File c:\Users\black\Research\.venv\Lib\site-packages\zmq\sugar\socket.py:698, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     691         data = zmq.Frame(
#     692             data,
#     693             track=track,
#     694             copy=copy or None,
#     695             copy_threshold=self.copy_threshold,
#     696         )
#     697     data.group = group
# --> 698 return super().send(data, flags=flags, copy=copy, track=track)
#
# File c:\Users\black\Research\.venv\Lib\site-packages\zmq\backend\cython\_zmq.py:1152, in zmq.backend.cython._zmq.Socket.send()
#
# File c:\Users\black\Research\.venv\Lib\site-packages\zmq\backend\cython\_zmq.py:1200, in zmq.backend.cython._zmq.Socket.send()
#
# File c:\Users\black\Research\.venv\Lib\site-packages\zmq\backend\cython\_zmq.py:1468, in zmq.backend.cython._zmq._send_copy()
#
# File c:\Users\black\Research\.venv\Lib\site-packages\zmq\backend\cython\_zmq.py:179, in zmq.backend.cython._zmq._check_rc()
#
# KeyboardInterrupt:
